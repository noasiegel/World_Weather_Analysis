# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-90.000, high=90.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 732

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')     
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description})

    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mahebourg
# Processing Record 2 of Set 1 | bathsheba
# Processing Record 3 of Set 1 | klaksvik
# Processing Record 4 of Set 1 | mehamn
# Processing Record 5 of Set 1 | tessalit
# Processing Record 6 of Set 1 | shache
# Processing Record 7 of Set 1 | iqaluit
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | saint-philippe
# Processing Record 10 of Set 1 | dikson
# Processing Record 11 of Set 1 | vardo
# Processing Record 12 of Set 1 | castro
# Processing Record 13 of Set 1 | bubaque
# Processing Record 14 of Set 1 | ust-koksa
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | carauari
# Processing Record 17 of Set 1 | arlit
# Processing Record 18 of Set 1 | cumaribo
# City not found. Skipping...
# Processing Record 19 of Set 1 | hithadhoo
# Processing Record 20 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 1 | gazojak
# Processing Record 22 of Set 1 | luderitz
# Processing Record 23 of Set 1 | tasiilaq
# Processing Record 24 of Set 1 | manjacaze
# Processing Record 25 of Set 1 | hofn
# Processing Record 26 of Set 1 | saldanha
# Processing Record 27 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 1 | victoria
# Processing Record 29 of Set 1 | rawson
# Processing Record 30 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 1 | qaanaaq
# Processing Record 32 of Set 1 | potoci
# Processing Record 33 of Set 1 | kinna
# Processing Record 34 of Set 1 | dhidhdhoo
# Processing Record 35 of Set 1 | jamestown
# Processing Record 36 of Set 1 | ostrovnoy
# Processing Record 37 of Set 1 | buqayq
# City not found. Skipping...
# Processing Record 38 of Set 1 | mar del plata
# Processing Record 39 of Set 1 | coihueco
# Processing Record 40 of Set 1 | veraval
# Processing Record 41 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 1 | accra
# Processing Record 43 of Set 1 | qaqortoq
# Processing Record 44 of Set 1 | cape town
# Processing Record 45 of Set 1 | bengkulu
# Processing Record 46 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 1 | port alfred
# Processing Record 48 of Set 1 | punta arenas
# Processing Record 49 of Set 1 | hualmay
# Processing Record 50 of Set 1 | souillac
# Processing Record 1 of Set 2 | azacualpa
# Processing Record 2 of Set 2 | port elizabeth
# Processing Record 3 of Set 2 | talnakh
# Processing Record 4 of Set 2 | torbay
# Processing Record 5 of Set 2 | longyearbyen
# Processing Record 6 of Set 2 | bababe
# City not found. Skipping...
# Processing Record 7 of Set 2 | cap malheureux
# Processing Record 8 of Set 2 | douentza
# Processing Record 9 of Set 2 | nieuw amsterdam
# Processing Record 10 of Set 2 | lagoa
# Processing Record 11 of Set 2 | pereslavl-zalesskiy
# Processing Record 12 of Set 2 | faya
# Processing Record 13 of Set 2 | bolshevik
# Processing Record 14 of Set 2 | padang
# Processing Record 15 of Set 2 | faratsiho
# Processing Record 16 of Set 2 | upernavik
# Processing Record 17 of Set 2 | abu samrah
# Processing Record 18 of Set 2 | manica
# Processing Record 19 of Set 2 | narsaq
# Processing Record 20 of Set 2 | intipuca
# Processing Record 21 of Set 2 | xai-xai
# Processing Record 22 of Set 2 | saint-augustin
# Processing Record 23 of Set 2 | shchigry
# Processing Record 24 of Set 2 | coquimbo
# Processing Record 25 of Set 2 | sao filipe
# Processing Record 26 of Set 2 | ribeira grande
# Processing Record 27 of Set 2 | parsabad
# Processing Record 28 of Set 2 | knysna
# Processing Record 29 of Set 2 | gat
# Processing Record 30 of Set 2 | yefimovskiy
# City not found. Skipping...
# Processing Record 31 of Set 2 | turkmenabat
# Processing Record 32 of Set 2 | clyde river
# Processing Record 33 of Set 2 | richards bay
# Processing Record 34 of Set 2 | nicoya
# Processing Record 35 of Set 2 | port-gentil
# Processing Record 36 of Set 2 | tahoua
# Processing Record 37 of Set 2 | nanortalik
# Processing Record 38 of Set 2 | mazagao
# Processing Record 39 of Set 2 | ambodifototra
# City not found. Skipping...
# Processing Record 40 of Set 2 | busselton
# Processing Record 41 of Set 2 | codrington
# Processing Record 42 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 2 | namibe
# Processing Record 44 of Set 2 | sioux lookout
# Processing Record 45 of Set 2 | moyale
# Processing Record 46 of Set 2 | east london
# Processing Record 47 of Set 2 | marawi
# Processing Record 48 of Set 2 | batetskiy
# Processing Record 49 of Set 2 | malwan
# City not found. Skipping...
# Processing Record 50 of Set 2 | pietersburg
# Processing Record 1 of Set 3 | kondol
# Processing Record 2 of Set 3 | tawnat
# City not found. Skipping...
# Processing Record 3 of Set 3 | berlevag
# Processing Record 4 of Set 3 | cidreira
# Processing Record 5 of Set 3 | rondonopolis
# Processing Record 6 of Set 3 | ponta do sol
# Processing Record 7 of Set 3 | lebu
# Processing Record 8 of Set 3 | road town
# Processing Record 9 of Set 3 | bougouni
# Processing Record 10 of Set 3 | yokadouma
# Processing Record 11 of Set 3 | margate
# Processing Record 12 of Set 3 | tara
# Processing Record 13 of Set 3 | natal
# Processing Record 14 of Set 3 | ornskoldsvik
# Processing Record 15 of Set 3 | chuy
# Processing Record 16 of Set 3 | disna
# Processing Record 17 of Set 3 | sao luiz gonzaga
# Processing Record 18 of Set 3 | korla
# Processing Record 19 of Set 3 | mana
# Processing Record 20 of Set 3 | beyneu
# Processing Record 21 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 22 of Set 3 | sorrento
# Processing Record 23 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 24 of Set 3 | jutai
# Processing Record 25 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 3 | korampallam
# Processing Record 27 of Set 3 | katrineholm
# Processing Record 28 of Set 3 | praia da vitoria
# Processing Record 29 of Set 3 | marienburg
# Processing Record 30 of Set 3 | frederick
# Processing Record 31 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 3 | saquisili
# Processing Record 33 of Set 3 | makokou
# Processing Record 34 of Set 3 | los llanos de aridane
# Processing Record 35 of Set 3 | luanda
# Processing Record 36 of Set 3 | mut
# Processing Record 37 of Set 3 | melfi
# Processing Record 38 of Set 3 | boralday
# Processing Record 39 of Set 3 | riyadh
# Processing Record 40 of Set 3 | la mana
# Processing Record 41 of Set 3 | rio grande
# Processing Record 42 of Set 3 | sarab
# Processing Record 43 of Set 3 | baramati
# Processing Record 44 of Set 3 | grindavik
# Processing Record 45 of Set 3 | marsaxlokk
# Processing Record 46 of Set 3 | cedeno
# Processing Record 47 of Set 3 | yurga
# Processing Record 48 of Set 3 | olafsvik
# Processing Record 49 of Set 3 | bambous virieux
# Processing Record 50 of Set 3 | laguna
# Processing Record 1 of Set 4 | venado tuerto
# Processing Record 2 of Set 4 | kortkeros
# Processing Record 3 of Set 4 | mandera
# Processing Record 4 of Set 4 | kruisfontein
# Processing Record 5 of Set 4 | bandarbeyla
# Processing Record 6 of Set 4 | panagar
# Processing Record 7 of Set 4 | georgetown
# Processing Record 8 of Set 4 | aranos
# Processing Record 9 of Set 4 | baie-comeau
# Processing Record 10 of Set 4 | leh
# Processing Record 11 of Set 4 | volosovo
# Processing Record 12 of Set 4 | mocuba
# Processing Record 13 of Set 4 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 14 of Set 4 | troy
# Processing Record 15 of Set 4 | salinopolis
# Processing Record 16 of Set 4 | husavik
# Processing Record 17 of Set 4 | beira
# Processing Record 18 of Set 4 | olinda
# Processing Record 19 of Set 4 | paamiut
# Processing Record 20 of Set 4 | yozgat
# Processing Record 21 of Set 4 | roald
# Processing Record 22 of Set 4 | saint george
# Processing Record 23 of Set 4 | pangnirtung
# Processing Record 24 of Set 4 | stanovoye
# Processing Record 25 of Set 4 | atar
# Processing Record 26 of Set 4 | thompson
# Processing Record 27 of Set 4 | leesburg
# Processing Record 28 of Set 4 | bosaso
# Processing Record 29 of Set 4 | raga
# Processing Record 30 of Set 4 | codajas
# Processing Record 31 of Set 4 | saint-georges
# Processing Record 32 of Set 4 | lawar
# City not found. Skipping...
# Processing Record 33 of Set 4 | vila velha
# Processing Record 34 of Set 4 | astana
# Processing Record 35 of Set 4 | barao de melgaco
# Processing Record 36 of Set 4 | korem
# Processing Record 37 of Set 4 | bredasdorp
# Processing Record 38 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 39 of Set 4 | nouadhibou
# Processing Record 40 of Set 4 | bonavista
# Processing Record 41 of Set 4 | muisne
# Processing Record 42 of Set 4 | mayumba
# Processing Record 43 of Set 4 | savona
# Processing Record 44 of Set 4 | bar harbor
# Processing Record 45 of Set 4 | itarantim
# Processing Record 46 of Set 4 | aktau
# Processing Record 47 of Set 4 | santa cruz
# Processing Record 48 of Set 4 | yining
# Processing Record 49 of Set 4 | el corpus
# Processing Record 50 of Set 4 | khndzoresk
# Processing Record 1 of Set 5 | kerchevskiy
# Processing Record 2 of Set 5 | bashmakovo
# Processing Record 3 of Set 5 | westport
# Processing Record 4 of Set 5 | narnaund
# Processing Record 5 of Set 5 | solwezi
# Processing Record 6 of Set 5 | gasa
# Processing Record 7 of Set 5 | serenje
# Processing Record 8 of Set 5 | izmit
# Processing Record 9 of Set 5 | makinsk
# Processing Record 10 of Set 5 | bani
# Processing Record 11 of Set 5 | inirida
# Processing Record 12 of Set 5 | maniitsoq
# Processing Record 13 of Set 5 | bentiu
# Processing Record 14 of Set 5 | umm kaddadah
# Processing Record 15 of Set 5 | nurota
# Processing Record 16 of Set 5 | jumla
# Processing Record 17 of Set 5 | segou
# Processing Record 18 of Set 5 | rocha
# Processing Record 19 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 20 of Set 5 | arraial do cabo
# Processing Record 21 of Set 5 | dire dawa
# Processing Record 22 of Set 5 | pudozh
# Processing Record 23 of Set 5 | taoudenni
# Processing Record 24 of Set 5 | puri
# Processing Record 25 of Set 5 | vestmanna
# Processing Record 26 of Set 5 | lexington park
# Processing Record 27 of Set 5 | neuquen
# Processing Record 28 of Set 5 | ondangwa
# Processing Record 29 of Set 5 | springbok
# Processing Record 30 of Set 5 | rio rita
# Processing Record 31 of Set 5 | saint-pierre
# Processing Record 32 of Set 5 | la valette-du-var
# Processing Record 33 of Set 5 | marrakesh
# Processing Record 34 of Set 5 | parana
# Processing Record 35 of Set 5 | ust-tsilma
# Processing Record 36 of Set 5 | peniche
# Processing Record 37 of Set 5 | eyrarbakki
# Processing Record 38 of Set 5 | gamba
# Processing Record 39 of Set 5 | mercedes
# Processing Record 40 of Set 5 | gryfino
# Processing Record 41 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 42 of Set 5 | damaturu
# Processing Record 43 of Set 5 | ust-kulom
# Processing Record 44 of Set 5 | tczew
# Processing Record 45 of Set 5 | bogandinskiy
# Processing Record 46 of Set 5 | vuktyl
# Processing Record 47 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 48 of Set 5 | gazanjyk
# Processing Record 49 of Set 5 | mocambique
# City not found. Skipping...
# Processing Record 50 of Set 5 | salalah
# Processing Record 1 of Set 6 | geraldton
# Processing Record 2 of Set 6 | balkhash
# Processing Record 3 of Set 6 | hamilton
# Processing Record 4 of Set 6 | oskemen
# Processing Record 5 of Set 6 | muros
# Processing Record 6 of Set 6 | havoysund
# Processing Record 7 of Set 6 | brufut
# Processing Record 8 of Set 6 | goundi
# Processing Record 9 of Set 6 | coihaique
# Processing Record 10 of Set 6 | matara
# Processing Record 11 of Set 6 | ilulissat
# Processing Record 12 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 13 of Set 6 | montevideo
# Processing Record 14 of Set 6 | moose factory
# Processing Record 15 of Set 6 | campamento
# Processing Record 16 of Set 6 | portage
# Processing Record 17 of Set 6 | santa vitoria do palmar
# Processing Record 18 of Set 6 | kwekwe
# Processing Record 19 of Set 6 | mahanoro
# Processing Record 20 of Set 6 | sayyan
# Processing Record 21 of Set 6 | verkhnyaya inta
# Processing Record 22 of Set 6 | tevriz
# Processing Record 23 of Set 6 | la rioja
# Processing Record 24 of Set 6 | san-pedro
# Processing Record 25 of Set 6 | cheremshanka
# Processing Record 26 of Set 6 | tucuman
# Processing Record 27 of Set 6 | bardiyah
# Processing Record 28 of Set 6 | yar-sale
# Processing Record 29 of Set 6 | sechura
# Processing Record 30 of Set 6 | kidal
# Processing Record 31 of Set 6 | nuuk
# Processing Record 32 of Set 6 | hobyo
# Processing Record 33 of Set 6 | perigueux
# Processing Record 34 of Set 6 | ghogha
# Processing Record 35 of Set 6 | ust-kan
# Processing Record 36 of Set 6 | quatre cocos
# Processing Record 37 of Set 6 | the valley
# Processing Record 38 of Set 6 | radchenko
# Processing Record 39 of Set 6 | asbe teferi
# Processing Record 40 of Set 6 | eirunepe
# Processing Record 41 of Set 6 | halifax
# Processing Record 42 of Set 6 | rastede
# Processing Record 43 of Set 6 | oeiras
# Processing Record 44 of Set 6 | puerto suarez
# Processing Record 45 of Set 6 | sinnamary
# Processing Record 46 of Set 6 | maragogi
# Processing Record 47 of Set 6 | tabou
# Processing Record 48 of Set 6 | mushie
# Processing Record 49 of Set 6 | key largo
# Processing Record 50 of Set 6 | takab
# Processing Record 1 of Set 7 | zabid
# Processing Record 2 of Set 7 | isiro
# Processing Record 3 of Set 7 | vagur
# Processing Record 4 of Set 7 | iskateley
# Processing Record 5 of Set 7 | pamplona
# Processing Record 6 of Set 7 | rovaniemi
# Processing Record 7 of Set 7 | carutapera
# Processing Record 8 of Set 7 | antofagasta
# Processing Record 9 of Set 7 | biltine
# Processing Record 10 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 11 of Set 7 | walhain
# Processing Record 12 of Set 7 | cape elizabeth
# City not found. Skipping...
# Processing Record 13 of Set 7 | nizwa
# Processing Record 14 of Set 7 | kaduqli
# Processing Record 15 of Set 7 | chicama
# Processing Record 16 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 17 of Set 7 | thinadhoo
# Processing Record 18 of Set 7 | ardistan
# City not found. Skipping...
# Processing Record 19 of Set 7 | cachoeiro de itapemirim
# Processing Record 20 of Set 7 | dakar
# Processing Record 21 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 7 | peterlee
# Processing Record 23 of Set 7 | kyabe
# Processing Record 24 of Set 7 | oriximina
# Processing Record 25 of Set 7 | esmeraldas
# Processing Record 26 of Set 7 | priiskovyy
# Processing Record 27 of Set 7 | abalak
# Processing Record 28 of Set 7 | ahar
# Processing Record 29 of Set 7 | japura
# Processing Record 30 of Set 7 | chapleau
# Processing Record 31 of Set 7 | walvis bay
# Processing Record 32 of Set 7 | buraydah
# Processing Record 33 of Set 7 | sorland
# Processing Record 34 of Set 7 | rio gallegos
# Processing Record 35 of Set 7 | umm lajj
# Processing Record 36 of Set 7 | maputo
# Processing Record 37 of Set 7 | kattivakkam
# Processing Record 38 of Set 7 | gibara
# Processing Record 39 of Set 7 | nuevitas
# Processing Record 40 of Set 7 | temizhbekskiy
# Processing Record 41 of Set 7 | wagar
# Processing Record 42 of Set 7 | itacare
# Processing Record 43 of Set 7 | am timan
# Processing Record 44 of Set 7 | iquitos
# Processing Record 45 of Set 7 | coari
# Processing Record 46 of Set 7 | sacramento
# Processing Record 47 of Set 7 | saint-francois
# Processing Record 48 of Set 7 | yarmouth
# Processing Record 49 of Set 7 | illapel
# Processing Record 50 of Set 7 | isla mujeres
# Processing Record 1 of Set 8 | oranjemund
# Processing Record 2 of Set 8 | soderhamn
# Processing Record 3 of Set 8 | karkaralinsk
# City not found. Skipping...
# Processing Record 4 of Set 8 | malangwa
# Processing Record 5 of Set 8 | pisco
# Processing Record 6 of Set 8 | gwadar
# Processing Record 7 of Set 8 | bajo baudo
# City not found. Skipping...
# Processing Record 8 of Set 8 | ardakan
# Processing Record 9 of Set 8 | dingle
# Processing Record 10 of Set 8 | faaborg
# Processing Record 11 of Set 8 | ancud
# Processing Record 12 of Set 8 | asfi
# Processing Record 13 of Set 8 | necochea
# Processing Record 14 of Set 8 | arshan
# Processing Record 15 of Set 8 | mizan teferi
# Processing Record 16 of Set 8 | maloy
# Processing Record 17 of Set 8 | sakakah
# Processing Record 18 of Set 8 | calais
# Processing Record 19 of Set 8 | aswan
# Processing Record 20 of Set 8 | touros
# Processing Record 21 of Set 8 | vsevolodo-vilva
# City not found. Skipping...
# Processing Record 22 of Set 8 | kismayo
# Processing Record 23 of Set 8 | huarmey
# Processing Record 24 of Set 8 | kumluca
# Processing Record 25 of Set 8 | trastenik
# Processing Record 26 of Set 8 | sompeta
# Processing Record 27 of Set 8 | brae
# Processing Record 28 of Set 8 | korhogo
# Processing Record 29 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 30 of Set 8 | roros
# Processing Record 31 of Set 8 | opuwo
# Processing Record 32 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 33 of Set 8 | bereda
# Processing Record 34 of Set 8 | zapolyarnyy
# Processing Record 35 of Set 8 | salinas
# Processing Record 36 of Set 8 | axim
# Processing Record 37 of Set 8 | korocha
# Processing Record 38 of Set 8 | aksarka
# Processing Record 39 of Set 8 | pindi gheb
# Processing Record 40 of Set 8 | tromso
# Processing Record 41 of Set 8 | groton
# Processing Record 42 of Set 8 | brigantine
# Processing Record 43 of Set 8 | toropets
# Processing Record 44 of Set 8 | yei
# Processing Record 45 of Set 8 | hambantota
# Processing Record 46 of Set 8 | jamame
# Processing Record 47 of Set 8 | lieksa
# Processing Record 48 of Set 8 | kedrovyy
# Processing Record 49 of Set 8 | vestmannaeyjar
# Processing Record 50 of Set 8 | breytovo
# Processing Record 1 of Set 9 | valparaiso
# Processing Record 2 of Set 9 | carapegua
# Processing Record 3 of Set 9 | skjervoy
# Processing Record 4 of Set 9 | durban
# Processing Record 5 of Set 9 | la roche-sur-yon
# Processing Record 6 of Set 9 | nantucket
# Processing Record 7 of Set 9 | sisimiut
# Processing Record 8 of Set 9 | dharmadam
# Processing Record 9 of Set 9 | ruangwa
# Processing Record 10 of Set 9 | ramhormoz
# Processing Record 11 of Set 9 | adrar
# Processing Record 12 of Set 9 | znamenskoye
# Processing Record 13 of Set 9 | yanam
# Processing Record 14 of Set 9 | miraflores
# Processing Record 15 of Set 9 | sur
# Processing Record 16 of Set 9 | porto empedocle
# Processing Record 17 of Set 9 | laukaa
# Processing Record 18 of Set 9 | mabaruma
# Processing Record 19 of Set 9 | aurillac
# Processing Record 20 of Set 9 | quelimane
# Processing Record 21 of Set 9 | namwala
# Processing Record 22 of Set 9 | viedma
# Processing Record 23 of Set 9 | cockburn town
# Processing Record 24 of Set 9 | khash
# Processing Record 25 of Set 9 | pinerolo
# Processing Record 26 of Set 9 | turbat
# Processing Record 27 of Set 9 | mayor pablo lagerenza
# Processing Record 28 of Set 9 | takoradi
# Processing Record 29 of Set 9 | lokoja
# Processing Record 30 of Set 9 | goksun
# Processing Record 31 of Set 9 | boca do acre
# Processing Record 32 of Set 9 | pinillos
# Processing Record 33 of Set 9 | senneterre
# Processing Record 34 of Set 9 | barcelos
# Processing Record 35 of Set 9 | maraa
# Processing Record 36 of Set 9 | port hawkesbury
# Processing Record 37 of Set 9 | bavleny
# Processing Record 38 of Set 9 | marsh harbour
# Processing Record 39 of Set 9 | gunjur
# Processing Record 40 of Set 9 | general pico
# Processing Record 41 of Set 9 | mantua
# Processing Record 42 of Set 9 | palmas bellas
# Processing Record 43 of Set 9 | dutse
# Processing Record 44 of Set 9 | achalpur
# Processing Record 45 of Set 9 | kudahuvadhoo
# Processing Record 46 of Set 9 | zaysan
# Processing Record 47 of Set 9 | kuminskiy
# Processing Record 48 of Set 9 | matiri
# Processing Record 49 of Set 9 | ilebo
# Processing Record 50 of Set 9 | high rock
# Processing Record 1 of Set 10 | saint-joseph
# Processing Record 2 of Set 10 | farafangana
# Processing Record 3 of Set 10 | vila franca do campo
# Processing Record 4 of Set 10 | menton
# Processing Record 5 of Set 10 | dibulla
# Processing Record 6 of Set 10 | verkhniy fiagdon
# Processing Record 7 of Set 10 | jalu
# Processing Record 8 of Set 10 | conde
# Processing Record 9 of Set 10 | uwayl
# City not found. Skipping...
# Processing Record 10 of Set 10 | bangassou
# Processing Record 11 of Set 10 | abonnema
# Processing Record 12 of Set 10 | maniwaki
# Processing Record 13 of Set 10 | ubinskoye
# Processing Record 14 of Set 10 | mpika
# Processing Record 15 of Set 10 | heidelberg
# Processing Record 16 of Set 10 | areosa
# Processing Record 17 of Set 10 | pyshma
# Processing Record 18 of Set 10 | san lawrenz
# Processing Record 19 of Set 10 | fuerte olimpo
# Processing Record 20 of Set 10 | awbari
# Processing Record 21 of Set 10 | kayerkan
# Processing Record 22 of Set 10 | alappuzha
# Processing Record 23 of Set 10 | jalingo
# Processing Record 24 of Set 10 | skalistyy
# City not found. Skipping...
# Processing Record 25 of Set 10 | coromandel
# Processing Record 26 of Set 10 | skibbereen
# Processing Record 27 of Set 10 | bagado
# Processing Record 28 of Set 10 | camana
# Processing Record 29 of Set 10 | ambovombe
# Processing Record 30 of Set 10 | kurchum
# Processing Record 31 of Set 10 | bay roberts
# Processing Record 32 of Set 10 | siderno
# Processing Record 33 of Set 10 | abu zabad
# Processing Record 34 of Set 10 | crixas
# Processing Record 35 of Set 10 | mongo
# Processing Record 36 of Set 10 | tazovskiy
# Processing Record 37 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 38 of Set 10 | leningradskiy
# Processing Record 39 of Set 10 | lemesos
# City not found. Skipping...
# Processing Record 40 of Set 10 | itarema
# Processing Record 41 of Set 10 | pachino
# Processing Record 42 of Set 10 | yako
# Processing Record 43 of Set 10 | galgani
# City not found. Skipping...
# Processing Record 44 of Set 10 | abu dhabi
# Processing Record 45 of Set 10 | najran
# Processing Record 46 of Set 10 | havelock
# Processing Record 47 of Set 10 | el tigre
# Processing Record 48 of Set 10 | sandviken
# Processing Record 49 of Set 10 | black river
# Processing Record 50 of Set 10 | conceicao do araguaia
# Processing Record 1 of Set 11 | dunmore east
# Processing Record 2 of Set 11 | havre-saint-pierre
# Processing Record 3 of Set 11 | kavaratti
# Processing Record 4 of Set 11 | mumford
# Processing Record 5 of Set 11 | san juan
# Processing Record 6 of Set 11 | ereymentau
# Processing Record 7 of Set 11 | ciras
# City not found. Skipping...
# Processing Record 8 of Set 11 | puerto del rosario
# Processing Record 9 of Set 11 | manacapuru
# Processing Record 10 of Set 11 | yelnya
# Processing Record 11 of Set 11 | sao paulo de olivenca
# Processing Record 12 of Set 11 | sargatskoye
# Processing Record 13 of Set 11 | nizhniy odes
# Processing Record 14 of Set 11 | begusarai
# Processing Record 15 of Set 11 | belyy yar
# Processing Record 16 of Set 11 | uspenka
# Processing Record 17 of Set 11 | kargil
# Processing Record 18 of Set 11 | loyga
# Processing Record 19 of Set 11 | chapais
# Processing Record 20 of Set 11 | qasigiannguit
# Processing Record 21 of Set 11 | vylkove
# Processing Record 22 of Set 11 | berbera
# Processing Record 23 of Set 11 | grand gaube
# Processing Record 24 of Set 11 | bako
# Processing Record 25 of Set 11 | campbeltown
# Processing Record 26 of Set 11 | novodolinskiy
# Processing Record 27 of Set 11 | kristinehamn
# Processing Record 28 of Set 11 | sept-iles
# Processing Record 29 of Set 11 | addis zemen
# City not found. Skipping...
# Processing Record 30 of Set 11 | aizpute
# Processing Record 31 of Set 11 | sayhat
# Processing Record 32 of Set 11 | ambilobe
# Processing Record 33 of Set 11 | zemio
# Processing Record 34 of Set 11 | grand-santi
# Processing Record 35 of Set 11 | cheuskiny
# City not found. Skipping...
# Processing Record 36 of Set 11 | cassilandia
# Processing Record 37 of Set 11 | strezhevoy
# Processing Record 38 of Set 11 | dalbandin
# Processing Record 39 of Set 11 | timizart
# Processing Record 40 of Set 11 | pimentel
# Processing Record 41 of Set 11 | atocha
# Processing Record 42 of Set 11 | keratea
# Processing Record 43 of Set 11 | tarpon springs
# Processing Record 44 of Set 11 | larsnes
# Processing Record 45 of Set 11 | marzuq
# Processing Record 46 of Set 11 | uray
# Processing Record 47 of Set 11 | cabedelo
# Processing Record 48 of Set 11 | lumeje
# Processing Record 49 of Set 11 | awjilah
# Processing Record 50 of Set 11 | kerki
# City not found. Skipping...
# Processing Record 1 of Set 12 | gazli
# Processing Record 2 of Set 12 | hagerstown
# Processing Record 3 of Set 12 | vila do maio
# Processing Record 4 of Set 12 | punuare
# Processing Record 5 of Set 12 | balykshi
# Processing Record 6 of Set 12 | greensboro
# Processing Record 7 of Set 12 | sainte-anne-des-monts
# Processing Record 8 of Set 12 | antalaha
# Processing Record 9 of Set 12 | dudinka
# Processing Record 10 of Set 12 | porto santo
# Processing Record 11 of Set 12 | iesolo
# Processing Record 12 of Set 12 | kirov
# Processing Record 13 of Set 12 | tyazhinskiy
# Processing Record 14 of Set 12 | mizdah
# Processing Record 15 of Set 12 | sussex
# Processing Record 16 of Set 12 | sao felix do xingu
# Processing Record 17 of Set 12 | inhambane
# Processing Record 18 of Set 12 | bermeo
# Processing Record 19 of Set 12 | totma
# Processing Record 20 of Set 12 | tortona
# Processing Record 21 of Set 12 | vallenar
# Processing Record 22 of Set 12 | sao joao da barra
# Processing Record 23 of Set 12 | san cristobal
# Processing Record 24 of Set 12 | aguilas
# Processing Record 25 of Set 12 | starcevo
# Processing Record 26 of Set 12 | pocone
# Processing Record 27 of Set 12 | mogadishu
# Processing Record 28 of Set 12 | iracoubo
# Processing Record 29 of Set 12 | tolmachevo
# Processing Record 30 of Set 12 | aviles
# Processing Record 31 of Set 12 | znamenka
# Processing Record 32 of Set 12 | kisangani
# Processing Record 33 of Set 12 | iberia
# Processing Record 34 of Set 12 | freetown
# Processing Record 35 of Set 12 | plaster rock
# Processing Record 36 of Set 12 | los palacios
# Processing Record 37 of Set 12 | cozumel
# Processing Record 38 of Set 12 | camacha
# Processing Record 39 of Set 12 | miragoane
# Processing Record 40 of Set 12 | belmonte
# Processing Record 41 of Set 12 | arkhangelsk
# Processing Record 42 of Set 12 | oktyabrskoye
# Processing Record 43 of Set 12 | diamantino
# Processing Record 44 of Set 12 | mbulu
# Processing Record 45 of Set 12 | lipin bor
# Processing Record 46 of Set 12 | laishevo
# Processing Record 47 of Set 12 | a
# City not found. Skipping...
# Processing Record 48 of Set 12 | buncrana
# Processing Record 49 of Set 12 | witu
# Processing Record 50 of Set 12 | makhinjauri
# Processing Record 1 of Set 13 | kolondieba
# Processing Record 2 of Set 13 | abha
# Processing Record 3 of Set 13 | comodoro rivadavia
# Processing Record 4 of Set 13 | maceio
# Processing Record 5 of Set 13 | adamas
# Processing Record 6 of Set 13 | sisian
# Processing Record 7 of Set 13 | oistins
# Processing Record 8 of Set 13 | imbituba
# Processing Record 9 of Set 13 | alta floresta
# Processing Record 10 of Set 13 | hagere hiywet
# Processing Record 11 of Set 13 | pozo colorado
# Processing Record 12 of Set 13 | benjamin constant
# Processing Record 13 of Set 13 | benghazi
# Processing Record 14 of Set 13 | novoagansk
# Processing Record 15 of Set 13 | kashi
# Processing Record 16 of Set 13 | tyulyachi
# Processing Record 17 of Set 13 | sharan
# Processing Record 18 of Set 13 | maxixe
# Processing Record 19 of Set 13 | eresos
# Processing Record 20 of Set 13 | hjallerup
# Processing Record 21 of Set 13 | perumpavur
# Processing Record 22 of Set 13 | carballo
# Processing Record 23 of Set 13 | moroni
# Processing Record 24 of Set 13 | bara
# Processing Record 25 of Set 13 | wattegama
# Processing Record 26 of Set 13 | behbahan
# Processing Record 27 of Set 13 | banes
# Processing Record 28 of Set 13 | capim grosso
# Processing Record 29 of Set 13 | lannion
# Processing Record 30 of Set 13 | omboue
# Processing Record 31 of Set 13 | imst
# Processing Record 32 of Set 13 | tucurui
# Processing Record 33 of Set 13 | koygorodok
# Processing Record 34 of Set 13 | camara de lobos
# Processing Record 35 of Set 13 | caraballeda
# Processing Record 36 of Set 13 | yenagoa
# Processing Record 37 of Set 13 | mto wa mbu
# Processing Record 38 of Set 13 | kananga
# Processing Record 39 of Set 13 | santa cruz de la palma
# Processing Record 40 of Set 13 | harer
# Processing Record 41 of Set 13 | quebo
# Processing Record 42 of Set 13 | tambura
# Processing Record 43 of Set 13 | liverpool
# Processing Record 44 of Set 13 | tvoroyri
# Processing Record 45 of Set 13 | rolim de moura
# City not found. Skipping...
# Processing Record 46 of Set 13 | parry sound
# Processing Record 47 of Set 13 | juazeiro do norte
# Processing Record 48 of Set 13 | jacareacanga
# Processing Record 49 of Set 13 | mezen
# Processing Record 50 of Set 13 | new york
# Processing Record 1 of Set 14 | igrim
# Processing Record 2 of Set 14 | shelburne
# Processing Record 3 of Set 14 | farafenni
# Processing Record 4 of Set 14 | itigi
# Processing Record 5 of Set 14 | tekstilshchik
# City not found. Skipping...
# Processing Record 6 of Set 14 | novyy svit
# Processing Record 7 of Set 14 | pinyug
# Processing Record 8 of Set 14 | oktyabrskaya
# City not found. Skipping...
# Processing Record 9 of Set 14 | polunochnoye
# Processing Record 10 of Set 14 | kongolo
# Processing Record 11 of Set 14 | ferme-neuve
# Processing Record 12 of Set 14 | tarhunah
# City not found. Skipping...
# Processing Record 13 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 14 of Set 14 | acarau
# Processing Record 15 of Set 14 | segezha
# Processing Record 16 of Set 14 | cayenne
# Processing Record 17 of Set 14 | joshimath
# Processing Record 18 of Set 14 | lesnoy
# Processing Record 19 of Set 14 | gaoua
# Processing Record 20 of Set 14 | ajaccio
# Processing Record 21 of Set 14 | eyl
# Processing Record 22 of Set 14 | filippias
# City not found. Skipping...
# Processing Record 23 of Set 14 | shakiso
# Processing Record 24 of Set 14 | zambezi
# Processing Record 25 of Set 14 | pietarsaari
# Processing Record 26 of Set 14 | cefalu
# Processing Record 27 of Set 14 | tiznit
# Processing Record 28 of Set 14 | bushehr
# Processing Record 29 of Set 14 | budhlada
# Processing Record 30 of Set 14 | nikolsk
# Processing Record 31 of Set 14 | guanica
# Processing Record 32 of Set 14 | giyani
# Processing Record 33 of Set 14 | nagua
# Processing Record 34 of Set 14 | karsun
# Processing Record 35 of Set 14 | atlantic city
# Processing Record 36 of Set 14 | puerto leguizamo
# Processing Record 37 of Set 14 | micheweni
# Processing Record 38 of Set 14 | sabratah
# Processing Record 39 of Set 14 | old road
# City not found. Skipping...
# Processing Record 40 of Set 14 | saint-orens-de-gameville
# Processing Record 41 of Set 14 | rincon
# Processing Record 42 of Set 14 | augusto correa
# Processing Record 43 of Set 14 | goderich
# Processing Record 44 of Set 14 | zyryanskoye
# Processing Record 45 of Set 14 | calama
# Processing Record 46 of Set 14 | kalmanka
# Processing Record 47 of Set 14 | ugoofaaru
# Processing Record 48 of Set 14 | harper
# Processing Record 49 of Set 14 | krasnoselkup
# Processing Record 50 of Set 14 | umba
# Processing Record 1 of Set 15 | dordrecht
# Processing Record 2 of Set 15 | peterhead
# Processing Record 3 of Set 15 | antu
# Processing Record 4 of Set 15 | puerto cortes
# City not found. Skipping...
# Processing Record 5 of Set 15 | perleberg
# Processing Record 6 of Set 15 | synya
# Processing Record 7 of Set 15 | jaisalmer
# Processing Record 8 of Set 15 | letterkenny
# Processing Record 9 of Set 15 | encruzilhada do sul
# Processing Record 10 of Set 15 | iralaya
# Processing Record 11 of Set 15 | tkvarcheli
# City not found. Skipping...
# Processing Record 12 of Set 15 | andenes
# Processing Record 13 of Set 15 | usogorsk
# Processing Record 14 of Set 15 | zgierz
# Processing Record 15 of Set 15 | okandja
# City not found. Skipping...
# Processing Record 16 of Set 15 | sao jose da coroa grande
# Processing Record 17 of Set 15 | winchester
# Processing Record 18 of Set 15 | uvat
# Processing Record 19 of Set 15 | asayita
# City not found. Skipping...
# Processing Record 20 of Set 15 | san pedro
# Processing Record 21 of Set 15 | aksu
# Processing Record 22 of Set 15 | aquiraz
# Processing Record 23 of Set 15 | tumaco
# Processing Record 24 of Set 15 | lvov
# Processing Record 25 of Set 15 | minab
# Processing Record 26 of Set 15 | ondjiva
# Processing Record 27 of Set 15 | santa isabel do rio negro
# Processing Record 28 of Set 15 | tyup
# Processing Record 29 of Set 15 | santander
# Processing Record 30 of Set 15 | pauini
# Processing Record 31 of Set 15 | andujar
# Processing Record 32 of Set 15 | kegayli
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 675

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0       Mahebourg -20.4081  57.7000     70.25        69          39
# 1       Bathsheba  13.2167 -59.5167     88.41        70          40
# 2        Klaksvik  62.2266  -6.5890     50.92        87          68
# 3          Mehamn  71.0357  27.8492     40.91       100         100
# 4        Tessalit  20.1986   1.0114     89.96        30          78
# 5          Shache  38.4167  77.2406     70.43        23         100
# 6         Iqaluit  63.7506 -68.5145     32.70        69          90
# 7        Hermanus -34.4187  19.2345     61.81        72         100
# 8  Saint-Philippe -21.3585  55.7679     69.39        77          41
# 9          Dikson  73.5069  80.5464     34.29        99         100
#
#    Wind Speed Country                 Date Current Description
# 0       14.20      MU  2022-10-01 17:08:19    scattered clouds
# 1       13.80      BB  2022-10-01 17:05:31    scattered clouds
# 2       17.25      FO  2022-10-01 17:08:20       broken clouds
# 3        2.30      NO  2022-10-01 17:08:06     overcast clouds
# 4        8.34      ML  2022-10-01 17:08:20       broken clouds
# 5       10.45      CN  2022-10-01 17:08:20     overcast clouds
# 6       20.00      CA  2022-10-01 17:08:11     overcast clouds
# 7        9.10      ZA  2022-10-01 17:08:21     overcast clouds
# 8       11.07      RE  2022-10-01 17:08:21    scattered clouds
# 9       13.65      RU  2022-10-01 17:08:22     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", 
                    "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_weather_data= city_data_df[new_column_order]

# Display sample data
city_weather_data.head()
# Out:
#         City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0  Mahebourg      MU -20.4081  57.7000     70.25        69          39
# 1  Bathsheba      BB  13.2167 -59.5167     88.41        70          40
# 2   Klaksvik      FO  62.2266  -6.5890     50.92        87          68
# 3     Mehamn      NO  71.0357  27.8492     40.91       100         100
# 4   Tessalit      ML  20.1986   1.0114     89.96        30          78
#
#    Wind Speed Current Description
# 0       14.20    scattered clouds
# 1       13.80    scattered clouds
# 2       17.25       broken clouds
# 3        2.30     overcast clouds
# 4        8.34       broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_weather_data.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
